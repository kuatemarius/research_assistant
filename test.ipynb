# %%
# !python -c "import microsoft_agents; import pkgutil; [print(m.name) for m in pkgutil.walk_packages(microsoft_agents.__path__, prefix='microsoft_agents.')]"
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     import microsoft_agents; import pkgutil; [print(m.name) for m in pkgutil.walk_packages(microsoft_agents.__path__, prefix='microsoft_agents.')]
#     ^^^^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'microsoft_agents'
